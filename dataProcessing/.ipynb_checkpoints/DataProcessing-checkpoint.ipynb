# %%
import pandas as pd
import numpy as np
ONLY_2016 = True

# %%
isa_courses_2016 = pd.read_csv('./data/ISA_romain/raph_coursecode_matching.csv')
isa_courses_2016.head()
# Out:
#    Unnamed: 0                                  SubjectName   SubjectID  \
# 0           0                 Histoire de l'architecture I     1773962
# 1           1                                  Stéréotomie  1769400055
# 2           2  Introduction aux outils CAO en architecture  1888400347
# 3           3                Théorie de l'architecture III     1776787
# 4           4               Histoire de l'architecture III     1773972
#
#     SectionName CourseCode   YearName
# 0  Architecture     AR-123  2015-2016
# 1  Architecture     AR-211  2015-2016
# 2  Architecture     AR-219  2015-2016
# 3  Architecture     AR-221  2015-2016
# 4  Architecture     AR-223  2015-2016

# %% [markdown]
# Let's use the data from ISA to filter Kshitij's data and keep only the courses from 2015-2016, as we're not interested in old courses:

# %%
# Note that this contains each course twice, once in english and once in french
max_courses_full = pd.read_csv('./data/Max/courses.csv')[['Code', 'Title']]
max_courses_full.head()
# Out:
#      Code                              Title
# 0  AR-101                         Studio BA1
# 1  AR-101  Théorie et critique du projet BA1
# 2  AR-102                         Studio BA2
# 3  AR-102  Théorie et critique du projet BA2
# 4  AR-111             Figuration graphique I

# %%
# Baseline edges scraped by Max
baseline_edges = pd.read_csv('./data/Max/edges/pre_obl.csv')[['Source', 'Target']]
baseline_edges.head()
# Out:
#    Source     Target
# 0  AR-112     AR-111
# 1  AR-211   MATH-121
# 2  AR-219   MATH-126
# 3  AR-231  CIVIL-122
# 4  AR-239  CIVIL-122

# %% [markdown]
# # Match Max's data with Kshitij's data
#
# The problem here is that Max's data was scraped from the web, and thus the courses do not have a subject ID. Also, the data was scraped in 2017, but the data from ISA that Kshitij used only goes until 2016.
# Therefore, the goal is to match the data by course code and/or course name as best as possible, considering that course codes/names can change over the years. Since this might create inconsistencies, I decided to process as follow:
# - The baseline (Max's scraped data) should stay true no matter what
# - Add as much edges from Kshitij's data as you can. It's fine if some are missing
# - It's okay if Kshitij's data has mistakes/inconsistencies, but try to avoid them as much as possible
#
# ### Data Exploration: Kshitij's data

# %%
courses_ksh = pd.read_csv('./data/Kshitij_new/isa-subject-id-name-code-hash.csv')
courses_ksh.head()
# Out:
#    SubjectID               SubjectName  \
# 0    1179233  Analyse I, II (allemand)
# 1    1179240        Algèbre linéaire I
# 2    1179245         Analyse numérique
# 3    1179253                Plan BA/MA
# 4    1186202       Algèbre linéaire II
#
#                                AssociatedCourseCodes
# 0                                                NaN
# 1  MATH-110; MATH-110(b); MATH-112; MATH-112(a); ...
# 2  MATH-150; MATH-250; MATH-251(a); MATH-251(b); ...
# 3                                                NaN
# 4       MATH-115; MATH-117; MATH-117(a); MATH-117(b)

# %%
print("There are " + str(courses_ksh.AssociatedCourseCodes.isnull().sum()) + "/" + str(len(courses_ksh)) + " courses with no codes")
# Out:
# There are 3278/6365 courses with no codes

# %%
grades_cor = pd.read_csv('./data/Kshitij_new/correlation-subject-pair.csv')[['sub1', 'sub2', 'cor1', 'pval1', 'cor2', 'pval2', 'sameSemester']]
grades_cor.head()
# Out:
#       sub1     sub2      cor1          pval1      cor2         pval2  \
# 0  1179240  1179245  0.479456   1.053786e-71  0.578663  1.057758e-13
# 1  1179240  1186202  0.638191  2.904612e-168  0.562914  1.925217e-17
# 2  1179240  1705532  0.491199   3.313850e-08  0.534409  7.964026e-13
# 3  1179240  1705538  0.601198   1.168207e-63  0.611785  6.559217e-15
# 4  1179240  1705590  0.488534   1.368027e-23  0.444710  6.189562e-12
#
#    sameSemester
# 0             0
# 1             2
# 2           594
# 3             0
# 4          1186

# %%
# Let's see how many edges we would have to drop if we drop all courses with no courseCode
courses_ksh_no_null = set(courses_ksh.dropna(subset=['AssociatedCourseCodes']).SubjectID.values)
#courses_ksh_no_null = courses_ksh[pd.notnull(courses_ksh['AssociatedCourseCodes'])]
print(len(courses_ksh_no_null))
n_drops_edges = 0
for row in grades_cor.values:
    if row[0] not in courses_ksh_no_null or row[1] not in courses_ksh_no_null:
        n_drops_edges += 1
print("We would drop " + str(n_drops_edges) + "/" + str(len(grades_cor)) + " edges if we drop all courses with no codes")
# Out:
# 3087
# We would drop 0/5828 edges if we drop all courses with no codes

# %% [markdown]
# It seems there is no edge from/to courses that have no course code. Thus, we can discard all the courses that have no code. \o/

# %%
# Drop the data with no course code
courses_ksh.dropna(subset=['AssociatedCourseCodes'], inplace=True)

# %% [markdown]
# ### Filter Kshitij's courses to keep only those from 2016

# %%
courses_ksh_2016 = courses_ksh[courses_ksh['SubjectID'].isin(isa_courses_2016['SubjectID'])]
courses_ksh_2016.head()
# Out:
#     SubjectID                                SubjectName  \
# 2     1179245                          Analyse numérique
# 14    1705590                                  Analyse I
# 18    1748172                       Analyse I (allemand)
# 19    1770632  Barrages et ouvrages hydrauliques annexes
# 22    1770678        Applied molecular quantum chemistry
#
#                                 AssociatedCourseCodes
# 2   MATH-150; MATH-250; MATH-251(a); MATH-251(b); ...
# 14  MATH-100; MATH-100(a); MATH-100(b); MATH-101(a...
# 18                             MATH-101(de); MATH-104
# 19                                          CIVIL-411
# 22                                             CH-451

# %%
if ONLY_2016:
    courses_ksh_final = courses_ksh_2016
else:
    courses_ksh_final = courses_ksh

# %% [markdown]
# - The unique courses will be courses_ksh_2016
# - The unique identifier will be the subject id
# - Process todo next:
#     - asssign the corresponding subjectID to each max_courses
#     - use that to translate the max_edges from code->code to subID->subID
#     - Now we have the baseline edges
#     - Then add the edges from Kshitij and get their directions with the grades file
#
# ## For each course of Max, find a subject ID
# ### Then, translate the baseline edges from (courseCode) <-> (courseCode) to (subID) <-> (subID)
# We can either matche the CC to the subIDs by course name, or by course code. I chose to match by course name, because it prevents mistakes (course codes can change over the years) due to the fact that both datasets are not from the same year

# %%
# join with course names
temp = courses_ksh_final
temp.index = courses_ksh_final.SubjectName
join_courses = max_courses_full.join(courses_ksh_final, on='Title')
join_courses = join_courses[pd.notnull(join_courses['SubjectName'])]
join_courses.drop(columns=['SubjectName', 'Title', 'AssociatedCourseCodes'], inplace=True)

# make a dict max_code -> subjectID
code_to_id = join_courses.set_index(join_courses['Code']).drop(columns=['Code']).to_dict()['SubjectID']

# translate the baseline edges
baseline_edges_final = baseline_edges[baseline_edges['Source'].isin(code_to_id) & baseline_edges['Target'].isin(code_to_id)].replace(code_to_id)
baseline_edges_final.head()
# Out:
#           Source        Target
# 9   7.147139e+07  2.381526e+07
# 12  3.510539e+08  1.772025e+06
# 13  3.522523e+08  1.772095e+06
# 19  1.678983e+09  1.678983e+09
# 21  1.773437e+06  1.772095e+06

# %%
count = 0
missed_edges = []
missed_nodes = set()
for row in baseline_edges.values:
    if row[0] in code_to_id and row[1] in code_to_id:
        count += 1
    if row[0] not in code_to_id:
        missed_nodes.add(row[0])
    if row[1] not in  code_to_id:
        missed_nodes.add(row[1])
print('We will keep ' + str(count) + '/' + str(baseline_edges.shape[0]) + ' baseline edges')
# Out:
# We will keep 60/226 baseline edges

# %% [markdown]
# ### Let's try to match the courses by code to see if we can keep more baseline edges:

# %%
import copy
# Try to match the missing baseline edges by course code
new_code_to_id = copy.deepcopy(code_to_id)
count = 0
for row in courses_ksh_2016.values:
    codes = row[2].split('; ')
    for node in missed_nodes:
        if node in codes:
            new_code_to_id[node] = row[0]
            count += 1
print(count)
# Out:
# 14

# %%
count = 0
missed_edges = []
missed_nodes = set()
for row in baseline_edges.values:
    if row[0] in new_code_to_id and row[1] in new_code_to_id:
        count += 1
    if row[0] not in code_to_id:
        missed_nodes.add(row[0])
    if row[1] not in  code_to_id:
        missed_nodes.add(row[1])
print('We will keep ' + str(count) + '/' + str(baseline_edges.shape[0]) + ' baseline edges')
# Out:
# We will keep 75/226 baseline edges

# %% [markdown]
# ## Process Kshitij's edges (Solution 1)
# The first solution is to take from the LDA edges all the pair of courses that appear in the grades correlations, so that we can infer their direction for the correlation. However, the two files only have ~100 common edges, which is really not enough.

# %%
# build dict name -> id
name_to_id = dict()
for row in courses_ksh_final.values:
    name_to_id[row[1]]= row[0]

# %% [markdown]
# ### Import edges and find subjectIDs of their endpoints
#
# Choose if you want to make the match the courses by ID or by name:

# %%
# import the edges
lda_edges = pd.read_csv('./data/Kshitij_old/edge_list_inf1_lda.csv', error_bad_lines=False)

# match with names
'''
lda_edges = lda_edges[lda_edges['course1'].isin(courses_ksh_final.SubjectName) & lda_edges['course2'].isin(courses_ksh_final.SubjectName)]
# rename the lda edges
lda_edges['ID1'] = lda_edges.course1.replace(name_to_id)
lda_edges['ID2'] = lda_edges.course2.replace(name_to_id)
'''


# or match with IDs
lda_edges = lda_edges[lda_edges['code1'].isin(code_to_id) & lda_edges['code2'].isin(code_to_id)]
# rename the lda edges
lda_edges['ID1'] = lda_edges.code1.replace(code_to_id)
lda_edges['ID2'] = lda_edges.code2.replace(code_to_id)
# Out:
# b'Skipping line 5142: expected 4 fields, saw 5\nSkipping line 5146: expected 4 fields, saw 6\nSkipping line 5518: expected 4 fields, saw 8\nSkipping line 6462: expected 4 fields, saw 5\nSkipping line 6666: expected 4 fields, saw 6\nSkipping line 7607: expected 4 fields, saw 6\nSkipping line 8660: expected 4 fields, saw 5\n'

# %%
# drop unnececary columns
lda_edges_final = lda_edges.drop(['code1', 'code2', 'course1', 'course2'], axis=1)
lda_edges_final.head()
lda_edges_final.shape
# Out:
# (1593, 2)

# %% [markdown]
# ### Match edges and grades correlations

# %%
# create the set of edges by taking each edge of the lda_edge_set if it has a correspondance in the grade set
# if there is a correspondance, use it to find the direction of the edge
'''
lda_edges_final_dict = dict()
i = 0
for edge in lda_edges_final.values:
    i += 1
    if i % 100 == 0:
        print(str(int(100*i/lda_edges_final.shape[0])) + '%')
    for row in grades_cor.values:
        if (int(edge[0]) == int(row[0]) and int(edge[1]) == int(row[1])) or (int(edge[0]) == int(row[1]) and int(edge[1]) == int(row[0])):
            if row[2] > row[4]:
                lda_edges_final_dict[row[0]] = row[1]
            else:
                lda_edges_final_dict[row[1]] = row[0]
'''
# Out:
# "\nlda_edges_final_dict = dict()\ni = 0\nfor edge in lda_edges_final.values:\n    i += 1\n    if i % 100 == 0:\n        print(str(int(100*i/lda_edges_final.shape[0])) + '%')\n    for row in grades_cor.values:\n        if (int(edge[0]) == int(row[0]) and int(edge[1]) == int(row[1])) or (int(edge[0]) == int(row[1]) and int(edge[1]) == int(row[0])):\n            if row[2] > row[4]:\n                lda_edges_final_dict[row[0]] = row[1]\n            else:\n                lda_edges_final_dict[row[1]] = row[0]\n"

# %%
#len(lda_edges_final_dict)
#lda_edges_final_dict

# %% [markdown]
# This is not satisfying, as the edges from Kshitij (PSLA, LDA, ...) are completly different from the 'grades corelations' pairs. Thus we only get directions for ~100 edges.
# ## The other solution: directly use the grades corelations as edges

# %%
edges_grades = pd.DataFrame()
edges_grades['Source'] = grades_cor.apply(lambda x: x[0] if x[2] > x[4] else x[1], axis=1)
edges_grades['Target'] = grades_cor.apply(lambda x: x[0] if x[2] <= x[4] else x[1], axis=1)
edges_grades['cor'] = grades_cor.apply(lambda x: max(x[2], x[4]), axis=1)
edges_grades['sameSemester'] = grades_cor['sameSemester']

# %%
edges_grades.head()
# Out:
#       Source     Target       cor  sameSemester
# 0  1179245.0  1179240.0  0.578663             0
# 1  1179240.0  1186202.0  0.638191             2
# 2  1705532.0  1179240.0  0.534409           594
# 3  1705538.0  1179240.0  0.611785             0
# 4  1179240.0  1705590.0  0.488534          1186

# %%
print(edges_grades.shape)
print(edges_grades[edges_grades.cor > 0.5].shape)
# Out:
# (5828, 4)
# (883, 4)

# %% [markdown]
# ### Keep only the edges from/to 2016 courses

# %%
# Keep only edges that have both endpoints in the courses' list and have a correlation > 0

correlation_threshold = 0

if ONLY_2016:
    edges_grades_final = edges_grades[edges_grades['Source'].isin(courses_ksh_2016.SubjectID) & edges_grades['Target'].isin(courses_ksh_2016.SubjectID)]
    edges_grades_final = edges_grades_final[edges_grades_final.cor > correlation_threshold][['Source', 'Target']]
else:
    edges_grades_final = edges_grades[edges_grades['Source'].isin(courses_ksh.SubjectID) & edges_grades['Target'].isin(courses_ksh.SubjectID)]
    edges_grades_final = edges_grades_final[edges_grades_final.cor > correlation_threshold][['Source', 'Target']]

print(edges_grades_final.shape)
# Out:
# (1255, 2)

# %% [markdown]
# ## Final Processing and Exporting

# %%
courses = courses_ksh_final.reset_index(drop=True).rename({'SubjectID':'Id'}, axis=1)

# add baseline/indicative label to edges
baseline_edges_final['type'] = 'baseline'
edges_grades_final['type'] = 'indicative'

edges = pd.concat([baseline_edges_final, edges_grades_final])

# %%
# Sanity check
print(edges['Source'].isin(courses.Id).all())
print(edges['Target'].isin(courses.Id).all())
# Out:
# True
# True

# %%
courses.to_csv('./data/output/courses_grades_2016.csv', index=False)
edges.to_csv('./data/output/edges_grades_2016.csv', index=False)

# %% [markdown]
# ## Third solution: Export the LDA edges and ignore the direction
# ### This is the solution that I used in the scope of my project
# Although it's not perfect, I made it very easy to replace the data in the front-end part so that when we get a consistent dataset from ISA we can very easily replace the dataset.

# %%
lda_edges_final.rename({'ID1':'Source', 'ID2':'Target'}, axis=1, inplace=True)
lda_edges_final['type'] = 'indicative'

edges = pd.concat([baseline_edges_final, lda_edges_final])
edges['Source'] = edges['Source'].astype(int)
edges['Target'] = edges['Target'].astype(int)
edges.to_csv('./data/output/edges_LDA_undir_2016.csv', index=False)

# %%
# Sanity check
print(edges['Source'].isin(courses.Id).all())
print(edges['Target'].isin(courses.Id).all())
# Out:
# True
# True

# %% [markdown]
# # Export courses' descriptions

# %%
descriptions = pd.read_csv('./data/course_descriptions.txt', sep='|')
descriptions.head()
# Out:
#    Unnamed: 0   SubjectID                                      CourseTitleEN  \
# 0         NaN    71468058   Studio BA1                                   ...
# 1         NaN    71468058   Studio BA2                                   ...
# 2         NaN     2978051   Graphic figuration I                         ...
# 3         NaN   348198884   Graphic figuration I                         ...
# 4         NaN  1769386510   Graphic figuration I                         ...
#
#        CourseCode                                         Summary_EN  \
# 0   AR-101          The semester focuses on the tools and process...
# 1   AR-102          Semester 2 provides a laboratory condition in...
# 2   AR-111          Initiation to the practice of architectural d...
# 3   AR-111          Initiation to the practice of architectural d...
# 4   AR-111          Initiation to the practice of architectural d...
#
#      AcademicYear Unnamed: 6
# 0   2016-2017            NaN
# 1   2016-2017            NaN
# 2   2016-2017            NaN
# 3   2016-2017            NaN
# 4   2016-2017            NaN

# %%
descriptions = descriptions[['SubjectID', 'Summary_EN']]
descriptions.Summary_EN = descriptions.Summary_EN.str.strip()
descriptions.SubjectID = descriptions.SubjectID.astype(int)
descriptions.drop_duplicates(subset=['SubjectID'], inplace=True)

# %%
descriptions_final = descriptions[descriptions['SubjectID'].isin(set(courses.Id))]
descriptions_final.head()
# Out:
#      SubjectID                                         Summary_EN
# 10     1773962  Contemporary architecture is heir to 5,000 yea...
# 34  1769400055  In the history of architecture, stereotomy is ...
# 37  1888400347  Based around the theme of stereotomy, the stud...
# 38     1776787  This course offers an overview of architectura...
# 40     1773972  The course aims to study the architecture of t...

# %%
# sanity check
assert(set(descriptions_final.SubjectID).issubset(set(courses.Id)))

# %%
# export the descriptions
descriptions_final.to_csv('./data/output/descriptions_raw.csv', sep='\t', index=False)

# %% [markdown]
# # Section names

# %%
sections = dict()
my_courses = set(courses.Id)
for row in isa_courses_2016.values:
    if(row[2] in my_courses):
        if(not row[2] in sections):
            sections[row[2]] = []
        sections[row[2]].append(row[3])
sections
# Out:
# {1179245: ['Mathématiques',
#   'Génie civil',
#   "Sciences et ingénierie de l'environnement",
#   'Passerelle HES - GC',
#   'Microtechnique',
#   'Génie électrique et électronique',
#   'Science et génie des matériaux',
#   'Passerelle HES - EL'],
#  1705590: ['Génie civil',
#   "Sciences et ingénierie de l'environnement",
#   'Chimie et génie chimique',
#   'Génie électrique et électronique',
#   'Science et génie des matériaux',
#   'Génie mécanique',
#   'Microtechnique',
#   'Systèmes de communication',
#   'Informatique',
#   'Sciences et technologies du vivant'],
#  1748172: ['Chimie et génie chimique',
#   'Génie civil',
#   'Microtechnique',
#   'Génie électrique et électronique',
#   'Génie mécanique',
#   'Science et génie des matériaux',
#   "Sciences et ingénierie de l'environnement",
#   'Sciences et technologies du vivant',
#   'Systèmes de communication',
#   'Informatique'],
#  1770632: ['Génie civil', 'Mineur en Énergie'],
#  1770678: ['Chimie moléculaire et biologique',
#   'Science et ingénierie computationnelles'],
#  1770798: ['Information security minor',
#   'UNIL - Sciences forensiques',
#   'Systèmes de communication - master'],
#  1770923: ['Systèmes de communication - master', 'Informatique'],
#  1770973: ['Information security minor',
#   'Systèmes de communication - master',
#   'Informatique'],
#  1771018: ['Bioingénierie',
#   'Mineur en Biocomputing',
#   'Mineur en Neurosciences computationnelles',
#   'Sciences et technologies du vivant - master',
#   'Science et ingénierie computationnelles',
#   'Systèmes de communication - master',
#   'Informatique',
#   'Mineur en Systems Engineering'],
#  1771058: ['Génie électrique et électronique',
#   'Systèmes de communication - master',
#   'Informatique'],
#  1771183: ["Gestion de l'énergie et construction durable",
#   'Ingénierie financière',
#   'Systèmes de communication - master',
#   'Informatique'],
#  1771203: ['Systèmes de communication', 'Informatique'],
#  1771468: ['Mineur en Biocomputing',
#   'Mineur en Neurosciences computationnelles',
#   'Sciences et technologies du vivant - master',
#   'Systèmes de communication - master',
#   'Informatique'],
#  1771488: ['Chimie moléculaire et biologique'],
#  1771538: ['Chimie moléculaire et biologique',
#   'Génie chimique et biotechnologie',
#   'Science et génie des matériaux'],
#  1771573: ["Gestion de l'énergie et construction durable",
#   'Génie chimique et biotechnologie',
#   'Mineur en Biotechnologie',
#   'Mineur en Énergie'],
#  1771718: ['Chimie moléculaire et biologique'],
#  1771764: ['Génie électrique et électronique',
#   'Information security minor',
#   'Systèmes de communication - master',
#   'Informatique'],
#  1771794: ['Mineur en Biocomputing',
#   'Mineur en Neurosciences computationnelles',
#   'Sciences et technologies du vivant - master',
#   'Systèmes de communication - master',
#   'Informatique'],
#  1771829: ['CMS'],
#  1771849: ['Architecture', 'Mineur en Développement territorial et urbanisme'],
#  1771905: ['Microtechnique'],
#  1772025: ['Sciences et technologies du vivant'],
#  1772030: ['Sciences et technologies du vivant'],
#  1772065: ['Systèmes de communication - master'],
#  1772075: ['Génie mécanique', 'Mineur en Technologies spatiales'],
#  1772085: ['Information security minor',
#   'Systèmes de communication',
#   'Informatique'],
#  1772095: ['Génie civil',
#   "Sciences et ingénierie de l'environnement",
#   'Chimie et génie chimique',
#   'Science et génie des matériaux',
#   'Génie mécanique',
#   'Microtechnique',
#   'Systèmes de communication',
#   'Informatique',
#   'Sciences et technologies du vivant',
#   'Génie électrique et électronique'],
#  1772230: ['Mathématiques',
#   'Génie électrique et électronique',
#   'Génie mécanique',
#   'Science et génie des matériaux',
#   'Passerelle HES - GM',
#   'Passerelle HES - EL',
#   'Microtechnique',
#   'Sciences et technologies du vivant',
#   'Passerelle HES - MT',
#   'Génie civil',
#   "Sciences et ingénierie de l'environnement",
#   'Passerelle HES - GC',
#   'Systèmes de communication',
#   'Informatique',
#   'Passerelle HES - IN'],
#  1772235: ['Systèmes de communication'],
#  1772250: ['Chimie et génie chimique', 'UNIL - Sciences forensiques'],
#  1772275: ['Passerelle HES - CGC'],
#  1772335: ['Génie mécanique'],
#  1772417: ['CMS'],
#  1772432: ['Passerelle HES - CGC'],
#  1772492: ['Chimie moléculaire et biologique',
#   'Génie chimique et biotechnologie',
#   'Mineur en Biotechnologie',
#   'UNIL - Sciences forensiques'],
#  1772497: ['Chimie et génie chimique'],
#  1772587: ['Chimie et génie chimique'],
#  1772657: ['Microtechnique',
#   'Génie électrique et électronique',
#   'Passerelle HES - EL'],
#  1772992: ['Programme Sciences humaines et sociales'],
#  1772997: ['Programme Sciences humaines et sociales'],
#  1773002: ['Programme Sciences humaines et sociales'],
#  1773287: ['Systèmes de communication - master', 'Informatique'],
#  1773337: ['Génie civil'],
#  1773402: ["Gestion de l'énergie et construction durable",
#   'Génie mécanique',
#   'Mineur en Énergie'],
#  1773427: ['Science et génie des matériaux'],
#  1773437: ['Chimie et génie chimique'],
#  1773442: ['Physique'],
#  1773452: ['Génie électrique et électronique',
#   'Systèmes de communication',
#   'Informatique',
#   'Passerelle HES - EL'],
#  1773472: ['Systèmes de communication', 'Informatique'],
#  1773492: ['Microtechnique',
#   'Génie électrique et électronique',
#   'Passerelle HES - EL',
#   'Systèmes de communication',
#   'Informatique'],
#  1773592: ["Gestion de l'énergie et construction durable",
#   'Génie civil',
#   'Mineur en Design intégré, architecture et durabilité',
#   'Mineur en Énergie'],
#  1773632: ["Gestion de l'énergie et construction durable",
#   'Génie civil',
#   'Mineur en Design intégré, architecture et durabilité',
#   'Mineur en Développement territorial et urbanisme',
#   "Sciences et ingénierie de l'environnement"],
#  1773647: ['Microtechnique',
#   'Génie mécanique',
#   'Mineur en Systems Engineering'],
#  1773682: ['Chimie et génie chimique', 'Passerelle HES - CGC'],
#  1773787: ['CMS'],
#  1773792: ['CMS'],
#  1773797: ['Mathématiques'],
#  1773822: ['Génie civil'],
#  1773962: ['Architecture'],
#  1773972: ['Architecture', 'Passerelle HES - AR'],
#  1773982: ['Architecture', 'Passerelle HES - AR'],
#  1774027: ['Génie civil', "Sciences et ingénierie de l'environnement"],
#  1774062: ['Génie électrique et électronique',
#   'Systèmes de communication - master'],
#  1774097: ['Mathématiques - master',
#   'Ingénierie mathématique',
#   'Génie électrique et électronique',
#   'Systèmes de communication - master',
#   'Informatique'],
#  1774102: ['CMS'],
#  1774172: ['Physique'],
#  1774457: ['Mineur en Technologies spatiales',
#   "Sciences et ingénierie de l'environnement"],
#  1774472: ['Génie mécanique'],
#  1774512: ['Mathématiques'],
#  1774522: ['Science et génie des matériaux'],
#  1774547: ['Génie civil'],
#  1774567: ['Génie civil', 'Passerelle HES - GC'],
#  1774642: ['Architecture', 'Passerelle HES - AR'],
#  1774677: ['Génie mécanique'],
#  1774762: ['Génie mécanique'],
#  1774797: ['Génie mécanique', 'Mineur en Technologies spatiales'],
#  1774827: ['Microtechnique', 'Passerelle HES - MT'],
#  1774837: ['Chimie et génie chimique', 'UNIL - Sciences forensiques'],
#  1774972: ['Science et génie des matériaux'],
#  1774997: ['Systèmes de communication', 'Informatique', 'Passerelle HES - SC'],
#  1775032: ['Architecture'],
#  1775157: ['Physique - master', 'Ingénierie physique'],
#  1775212: ['Physique - master', 'Ingénierie physique'],
#  1775277: ['CMS'],
#  1775332: ['Architecture'],
#  1775342: ['Architecture'],
#  1775352: ['Architecture', 'Passerelle HES - AR'],
#  1775372: ['Physique'],
#  1775382: ['Physique - master', 'Ingénierie physique'],
#  1775427: ['Génie civil',
#   "Sciences et ingénierie de l'environnement",
#   'Génie électrique et électronique',
#   'Science et génie des matériaux',
#   'Informatique',
#   'Génie mécanique',
#   'Microtechnique',
#   'Mathématiques',
#   'Systèmes de communication',
#   'Sciences et technologies du vivant',
#   'Chimie et génie chimique'],
#  1775452: ['Chimie et génie chimique',
#   'Sciences et technologies du vivant',
#   'Passerelle HES - CGC',
#   'Microtechnique',
#   'Génie électrique et électronique',
#   'Passerelle HES - EL',
#   'Passerelle HES - MT',
#   'Génie mécanique',
#   'Science et génie des matériaux',
#   'Passerelle HES - GM'],
#  1775477: ['Physique'],
#  1775497: ['Physique'],
#  1775507: ['Physique'],
#  1775517: ['Physique - master', 'Ingénierie physique'],
#  1775532: ['Physique'],
#  1775602: ['Génie civil'],
#  1775637: ['Mathématiques'],
#  1775642: ['Systèmes de communication',
#   'Physique',
#   'Génie civil',
#   'Passerelle HES - GC',
#   'Chimie et génie chimique',
#   'Génie mécanique',
#   'UNIL - Sciences forensiques',
#   'Passerelle HES - GM',
#   'Passerelle HES - CGC'],
#  1775647: ['Sciences et technologies du vivant'],
#  1775692: ['Génie civil', "Sciences et ingénierie de l'environnement"],
#  1775697: ['Microtechnique',
#   'Génie électrique et électronique',
#   'Mathématiques',
#   'Physique',
#   'Sciences et technologies du vivant'],
#  1775702: ['Sciences et technologies du vivant'],
#  1775757: ['Génie mécanique'],
#  1775782: ['Architecture', 'Génie civil'],
#  1775867: ['Génie mécanique'],
#  1775907: ['Microtechnique'],
#  1775912: ['Microtechnique'],
#  1776002: ['Génie électrique et électronique',
#   'Mineur en Technologies spatiales',
#   'Passerelle HES - EL'],
#  1776057: ['Génie électrique et électronique', 'Passerelle HES - EL'],
#  1776067: ['Information security minor',
#   'Systèmes de communication',
#   'Informatique',
#   'Passerelle HES - IN',
#   'Passerelle HES - SC'],
#  1776087: ['Systèmes de communication', 'Informatique'],
#  1776107: ['Microtechnique'],
#  1776342: ['Architecture'],
#  1776347: ['Systèmes de communication - master', 'Informatique'],
#  1776377: ['Mathématiques'],
#  1776477: ['Génie civil'],
#  1776592: ['Microtechnique'],
#  1776627: ['Microtechnique'],
#  1776687: ['Génie électrique et électronique'],
#  1776702: ['Microtechnique', 'Mineur en Technologies biomédicales'],
#  1776787: ['Architecture'],
#  1776797: ['Architecture', 'Passerelle HES - AR'],
#  1777057: ['Microtechnique'],
#  1777127: ["Gestion de l'énergie et construction durable",
#   'Génie mécanique',
#   'Génie nucléaire'],
#  1777132: ['Génie mécanique'],
#  2207995: ['Chimie et génie chimique',
#   'Génie civil',
#   'Mathématiques',
#   'Microtechnique',
#   'Génie électrique et électronique',
#   'Génie mécanique',
#   'Science et génie des matériaux',
#   "Sciences et ingénierie de l'environnement",
#   'Sciences et technologies du vivant',
#   'Systèmes de communication',
#   'Informatique'],
#  2208445: ['Génie civil'],
#  2214296: ["Sciences et ingénierie de l'environnement"],
#  2222268: ['Micro and Nanotechnologies for Integrated Systems',
#   'Génie électrique et électronique'],
#  2229035: ['Mathématiques'],
#  2258520: ['Systèmes de communication', 'Informatique'],
#  2258712: ['Systèmes de communication',
#   'Mathématiques',
#   'Information security minor',
#   'Science et ingénierie computationnelles',
#   'Informatique',
#   'Passerelle HES - IN',
#   'Passerelle HES - SC'],
#  2328456: ['Génie mécanique'],
#  2348799: ['Bioingénierie',
#   'Sciences et technologies du vivant - master',
#   'Systèmes de communication - master'],
#  3855141: ['Physique'],
#  4144648: ['Systèmes de communication', 'Informatique', 'Passerelle HES - IN'],
#  4144900: ['Chimie et génie chimique',
#   'Mathématiques',
#   'UNIL - Sciences forensiques',
#   'Passerelle HES - CGC'],
#  4145120: ['Génie chimique et biotechnologie', 'Mineur en Biotechnologie'],
#  4145236: ['Génie chimique et biotechnologie'],
#  4145668: ['Microtechnique', 'Passerelle HES - MT'],
#  4148121: ['Mathématiques'],
#  4150874: ['Mathématiques - master', 'Ingénierie mathématique'],
#  4151162: ['Information security minor',
#   'Systèmes de communication',
#   'Informatique'],
#  4151854: ['Architecture', 'Echange AR'],
#  4151954: ['Génie civil'],
#  4649823: ["Sciences et ingénierie de l'environnement"],
#  4651611: ['Sciences et technologies du vivant - master'],
#  22827171: ['Génie civil'],
#  23325791: ['Génie civil'],
#  23610182: ['Hors plans'],
#  23812659: ['Architecture',
#   'Mineur en Développement territorial et urbanisme'],
#  23813560: ['Architecture',
#   "Gestion de l'énergie et construction durable",
#   'Mineur en Design intégré, architecture et durabilité'],
#  23815258: ['Architecture', 'Echange AR'],
#  23939045: ['Microtechnique', 'Passerelle HES - MT'],
#  23985449: ["Sciences et ingénierie de l'environnement"],
#  23985644: ['Mineur en Design intégré, architecture et durabilité',
#   'Mineur en Énergie',
#   "Sciences et ingénierie de l'environnement"],
#  23996074: ['Bioingénierie',
#   'Microtechnique',
#   'Mineur en Technologies biomédicales',
#   'Sciences et technologies du vivant - master'],
#  23996396: ["Gestion de l'énergie et construction durable",
#   'Micro and Nanotechnologies for Integrated Systems',
#   'Microtechnique',
#   'Génie électrique et électronique'],
#  24002581: ['Mineur en Design intégré, architecture et durabilité',
#   "Sciences et ingénierie de l'environnement"],
#  24004448: ["Sciences et ingénierie de l'environnement"],
#  24005195: ["Sciences et ingénierie de l'environnement"],
#  24092923: ['Science et ingénierie computationnelles',
#   'Systèmes de communication',
#   'Informatique',
#   'Passerelle HES - IN'],
#  24102460: ['Génie électrique et électronique'],
#  24164994: ['Génie électrique et électronique',
#   'Systèmes de communication - master',
#   'Informatique'],
#  24165904: ['Génie électrique et électronique',
#   'Systèmes de communication - master',
#   'Informatique'],
#  24166696: ['Mineur en Technologies spatiales',
#   'Systèmes de communication - master'],
#  24174877: ['Architecture'],
#  24175202: ['Architecture'],
#  24261148: ['Architecture'],
#  24302061: ['Micro and Nanotechnologies for Integrated Systems',
#   'Génie électrique et électronique'],
#  24334799: ['Génie électrique et électronique'],
#  24335296: ['Génie électrique et électronique'],
#  24345947: ['Mathématiques'],
#  24346085: ['Mathématiques'],
#  24346308: ['Mathématiques'],
#  24346316: ['Mathématiques'],
#  24375105: ['Génie nucléaire', 'Physique - master', 'Ingénierie physique'],
#  24429568: ['Bioingénierie'],
#  24508366: ['Sciences et technologies du vivant'],
#  29870604: ['CMS'],
#  40249208: ['Micro and Nanotechnologies for Integrated Systems',
#   'Génie électrique et électronique'],
#  44378947: ['Physique - master', 'Ingénierie physique'],
#  44989325: ["Sciences et ingénierie de l'environnement"],
#  46641934: ['Génie civil'],
#  47233600: ['Microtechnique',
#   'Génie électrique et électronique',
#   'Mineur en Systems Engineering'],
#  47241891: ['Micro and Nanotechnologies for Integrated Systems',
#   'Génie électrique et électronique'],
#  47244272: ['Mineur en Technologies spatiales',
#   'Mineur en Systems Engineering'],
#  47390229: ['Génie civil'],
#  47564647: ['Mineur en Biotechnologie',
#   "Sciences et ingénierie de l'environnement"],
#  47565939: ['Génie civil', "Sciences et ingénierie de l'environnement"],
#  47572475: ["Gestion de l'énergie et construction durable",
#   'Mineur en Énergie',
#   "Sciences et ingénierie de l'environnement"],
#  47572529: ["Gestion de l'énergie et construction durable",
#   "Sciences et ingénierie de l'environnement",
#   'Science et ingénierie computationnelles'],
#  47572541: ["Gestion de l'énergie et construction durable",
#   "Sciences et ingénierie de l'environnement"],
#  47830388: ['Bioingénierie',
#   'Microtechnique',
#   'Génie électrique et électronique',
#   'Mineur en Technologies biomédicales',
#   'Sciences et technologies du vivant - master'],
#  47832968: ['Architecture'],
#  47848061: ['Information security minor',
#   'Systèmes de communication',
#   'Informatique'],
#  47947735: ['Sciences et technologies du vivant - master'],
#  47977389: ['Mathématiques'],
#  47980922: ['Mathématiques - master',
#   'Ingénierie mathématique',
#   "Mathématiques pour l'enseignement"],
#  47987731: ['Chimie et génie chimique'],
#  47994028: ['Bioingénierie',
#   'Microtechnique',
#   'Mineur en Biocomputing',
#   'Mineur en Neuroprosthétiques',
#   'Mineur en Neurosciences computationnelles',
#   'Sciences et technologies du vivant - master',
#   'Science et ingénierie computationnelles',
#   'Systèmes de communication - master',
#   'Informatique'],
#  47995206: ['Sciences et technologies du vivant - master'],
#  47997051: ['Management, technologie et entrepreneuriat',
#   'Mineur en Management, technologie et entrepreneuriat'],
#  48099118: ['Génie chimique et biotechnologie', 'Mineur en Énergie'],
#  48289169: ['Bioingénierie', 'Sciences et technologies du vivant - master'],
#  71466583: ['Architecture', 'Echange AR'],
#  71466740: ['Architecture'],
#  71470103: ['Architecture'],
#  71471393: ['Architecture', 'Echange AR'],
#  71471407: ['Architecture', 'Echange AR'],
#  71544480: ["Sciences et ingénierie de l'environnement"],
#  71544625: ['Génie civil', "Sciences et ingénierie de l'environnement"],
#  71556171: ["Sciences et ingénierie de l'environnement"],
#  71559290: ["Sciences et ingénierie de l'environnement"],
#  71603578: ['Microtechnique'],
#  71603711: ['Mineur en Neuroprosthétiques',
#   'Mineur en Technologies biomédicales',
#   'Systèmes de communication - master',
#   'Informatique'],
#  71629360: ['Science et génie des matériaux'],
#  71630664: ['Science et génie des matériaux'],
#  71630770: ['Science et génie des matériaux'],
#  71644441: ['Génie électrique et électronique',
#   'Systèmes de communication - master',
#   'Informatique'],
#  71645784: ['Systèmes de communication'],
#  71826349: ['Mineur en Biotechnologie',
#   "Sciences et ingénierie de l'environnement"],
#  71840397: ['Informatique'],
#  71855072: ['Chimie et génie chimique'],
#  71877719: ['Chimie moléculaire et biologique'],
#  71883318: ['Hors plans'],
#  71898059: ['Bioingénierie',
#   'Génie chimique et biotechnologie',
#   'Mineur en Biotechnologie',
#   'Sciences et technologies du vivant - master',
#   'Science et ingénierie computationnelles',
#   'Mineur en Systems Engineering'],
#  71966057: ['Management, technologie et entrepreneuriat',
#   'Mineur en Management, technologie et entrepreneuriat',
#   'Ingénierie financière'],
#  72257890: ['Génie mécanique', 'Science et génie des matériaux'],
#  72259375: ['Hors plans'],
#  72259536: ['Mineur en Énergie'],
#  72259583: ['Systèmes de communication'],
#  72259597: ['Mineur en Technologies spatiales'],
#  72259676: ['Génie civil'],
#  72260050: ['Hors plans'],
#  72495962: ["Gestion de l'énergie et construction durable",
#   "Sciences et ingénierie de l'environnement"],
#  72496701: ["Gestion de l'énergie et construction durable",
#   "Sciences et ingénierie de l'environnement"],
#  72497223: ['Mineur en Design intégré, architecture et durabilité',
#   "Sciences et ingénierie de l'environnement"],
#  75309053: ['Génie électrique et électronique'],
#  80395102: ['Ingénierie financière'],
#  80958519: ['Programme Sciences humaines et sociales'],
#  82805306: ['Systèmes de communication - master'],
#  85594280: ['CMS'],
#  90181927: ['Echange GC',
#   'Echange EL',
#   'Echange GM',
#   'Echange MX',
#   'Echange PH',
#   'Echange IN',
#   'Echange SC'],
#  125910731: ['Génie civil'],
#  126727237: ['Architecture'],
#  126877750: ['Bioingénierie', 'Génie mécanique'],
#  127005949: ['Mineur en Technologies spatiales'],
#  127857132: ['Mineur en Énergie', 'Physique - master', 'Ingénierie physique'],
#  128314283: ['Systèmes de communication'],
#  128342116: ['Science et génie des matériaux',
#   'Physique - master',
#   'Ingénierie physique'],
#  128676455: ['Informatique'],
#  128676975: ['Informatique'],
#  128690863: ['Physique - master', 'Ingénierie physique'],
#  128789807: ['Génie électrique et électronique',
#   'Science et ingénierie computationnelles',
#   'Systèmes de communication - master',
#   'Informatique'],
#  128846720: ["Gestion de l'énergie et construction durable",
#   'Génie nucléaire'],
#  128847590: ['Physique - master', 'Ingénierie physique'],
#  128848626: ['Physique - master',
#   'Ingénierie physique',
#   'Science et ingénierie computationnelles'],
#  128851000: ['Génie nucléaire', 'Physique - master', 'Ingénierie physique'],
#  128851631: ['Bioingénierie',
#   'Physique - master',
#   'Ingénierie physique',
#   'Sciences et technologies du vivant - master'],
#  128851781: ['Physique - master', 'Ingénierie physique'],
#  128851969: ['Mathématiques - master',
#   'Ingénierie mathématique',
#   'Physique - master',
#   'Ingénierie physique'],
#  128852199: ['Génie nucléaire', 'Physique - master', 'Ingénierie physique'],
#  129285391: ['Génie nucléaire'],
#  129286243: ['Génie nucléaire'],
#  129609800: ['Mathématiques'],
#  129686166: ['Mathématiques - master', 'Ingénierie mathématique'],
#  129687015: ['Ingénierie mathématique'],
#  129688728: ["Gestion de l'énergie et construction durable",
#   'Mathématiques - master',
#   'Ingénierie mathématique',
#   'Ingénierie financière',
#   'Science et ingénierie computationnelles'],
#  129699210: ['Ingénierie financière'],
#  129776728: ['Chimie moléculaire et biologique'],
#  129833984: ['Chimie moléculaire et biologique'],
#  129871669: ['Mathématiques - master', 'Ingénierie mathématique'],
#  130130740: ['Génie chimique et biotechnologie',
#   'Mineur en Énergie',
#   'Passerelle HES - CGC'],
#  132121224: ['Sciences et technologies du vivant'],
#  132147064: ['Bioingénierie',
#   'Génie mécanique',
#   'Mineur en Technologies biomédicales'],
#  132424187: ['Génie mécanique'],
#  132424568: ['Microtechnique'],
#  132424935: ['Génie électrique et électronique'],
#  132425231: ['Systèmes de communication - master'],
#  132425627: ['Physique - master', 'Ingénierie physique'],
#  132425754: ['Chimie moléculaire et biologique'],
#  132426961: ['Ingénierie mathématique', 'Mathématiques - master'],
#  132427120: ['Informatique'],
#  132428658: ['Science et génie des matériaux'],
#  132446543: ['Architecture'],
#  132448364: ['Sciences et technologies du vivant - master'],
#  132448731: ['Management, technologie et entrepreneuriat'],
#  132449292: ['Ingénierie financière'],
#  134468934: ['Génie civil'],
#  134558496: ["Sciences et ingénierie de l'environnement"],
#  134558590: ['Bioingénierie'],
#  136703631: ['Génie civil'],
#  136704168: ['Génie civil'],
#  136704309: ['Génie civil'],
#  138587084: ['Physique - master', 'Ingénierie physique'],
#  146861779: ['Génie mécanique'],
#  161867929: ['Génie nucléaire'],
#  161868049: ['Génie nucléaire'],
#  227234245: ['Architecture', 'Echange AR'],
#  227318424: ['Génie civil'],
#  228377622: ["Gestion de l'énergie et construction durable",
#   'Génie mécanique',
#   'Mineur en Énergie'],
#  228381203: ["Gestion de l'énergie et construction durable",
#   'Microtechnique',
#   'Génie mécanique'],
#  228383796: ["Gestion de l'énergie et construction durable",
#   'Génie mécanique'],
#  228388747: ["Gestion de l'énergie et construction durable",
#   'Génie mécanique',
#   'Science et ingénierie computationnelles'],
#  228390459: ["Gestion de l'énergie et construction durable",
#   'Management, technologie et entrepreneuriat',
#   'Génie mécanique'],
#  229613299: ['Mineur en Technologies biomédicales'],
#  229720940: ['Mathématiques - master',
#   'Ingénierie mathématique',
#   'Génie électrique et électronique',
#   'Mineur en Technologies biomédicales',
#   'Systèmes de communication - master',
#   'Informatique'],
#  229734572: ['Chimie moléculaire et biologique',
#   'Mineur en Technologies biomédicales'],
#  229734640: ['Mineur en Neuroprosthétiques', 'Science et génie des matériaux'],
#  229912643: ['Management, technologie et entrepreneuriat',
#   'Mineur en Management, technologie et entrepreneuriat'],
#  229913760: ['Ingénierie financière'],
#  229971214: ['Génie civil', 'Passerelle HES - GC'],
#  229987786: ['Ingénierie financière'],
#  229988060: ['Ingénierie financière'],
#  229988298: ['Ingénierie financière'],
#  230003664: ['Ingénierie financière'],
#  230301204: ['Mathématiques - master',
#   'Ingénierie mathématique',
#   'Science et ingénierie computationnelles'],
#  230597543: ['Mathématiques'],
#  230665709: ['Chimie et génie chimique'],
#  230666083: ['Mineur en Biocomputing',
#   'Science et ingénierie computationnelles',
#   'Passerelle HES - CGC'],
#  230672285: ['Mineur en Biotechnologie'],
#  230678232: ['Physique - master', 'Ingénierie physique'],
#  231606915: ['Génie civil', 'Passerelle HES - GC'],
#  231617900: ["Sciences et ingénierie de l'environnement"],
#  231672762: ["Gestion de l'énergie et construction durable",
#   "Sciences et ingénierie de l'environnement"],
#  231677206: ["Gestion de l'énergie et construction durable",
#   'Microtechnique',
#   'Mineur en Biocomputing',
#   "Sciences et ingénierie de l'environnement",
#   'Science et ingénierie computationnelles',
#   'Systèmes de communication - master',
#   'Informatique'],
#  231901032: ['Systèmes de communication - master', 'Informatique'],
#  231957235: ['Systèmes de communication - master'],
#  231957545: ['Informatique'],
#  231957812: ['Science et ingénierie computationnelles', 'Informatique'],
#  232289697: ['Mineur en Neurosciences computationnelles',
#   'Sciences et technologies du vivant - master'],
#  234597759: ['Génie chimique et biotechnologie'],
#  235424562: ['Programme Sciences humaines et sociales'],
#  235424693: ['Programme Sciences humaines et sociales'],
#  236283202: ['Ingénierie financière'],
#  241135439: ['Mineur en Technologies spatiales'],
#  243429820: ['Physique - master', 'Ingénierie physique'],
#  243791097: ['Science et ingénierie computationnelles'],
#  243791456: ['Science et ingénierie computationnelles'],
#  249353044: ['Programme Sciences humaines et sociales'],
#  249371091: ['Programme Sciences humaines et sociales'],
#  249730357: ['Programme Sciences humaines et sociales'],
#  249730431: ['Programme Sciences humaines et sociales'],
#  249735026: ['Programme Sciences humaines et sociales'],
#  249735109: ['Programme Sciences humaines et sociales'],
#  249735302: ['Programme Sciences humaines et sociales'],
#  249749117: ['Programme Sciences humaines et sociales'],
#  250986010: ['Chimie et génie chimique', 'Mineur en Biotechnologie'],
#  250991626: ['Chimie moléculaire et biologique',
#   'Science et ingénierie computationnelles'],
#  257434376: ['Sciences et technologies du vivant'],
#  260077392: ['Sciences et technologies du vivant'],
#  260079039: ['Chimie et génie chimique'],
#  266851392: ['Génie nucléaire'],
#  338340784: ["Gestion de l'énergie et construction durable", 'Génie civil'],
#  348210408: ['Architecture'],
#  348211982: ['Architecture'],
#  348607885: ['Génie civil',
#   'Mineur en Développement territorial et urbanisme',
#   'Passerelle HES - GC'],
#  348608416: ['Génie civil', "Sciences et ingénierie de l'environnement"],
#  348634646: ["Gestion de l'énergie et construction durable",
#   "Sciences et ingénierie de l'environnement"],
#  348637649: ["Gestion de l'énergie et construction durable",
#   "Sciences et ingénierie de l'environnement"],
#  348715502: ['Systèmes de communication',
#   'Génie électrique et électronique',
#   'Informatique',
#   'Passerelle HES - EL'],
#  348716744: ['Systèmes de communication'],
#  348760034: ['Génie électrique et électronique',
#   'Systèmes de communication - master',
#   'Informatique'],
#  350462476: ['Passerelle HES - CGC'],
#  350468544: ['UNIL - Sciences forensiques'],
#  350847112: ['Génie chimique et biotechnologie', 'Mineur en Biotechnologie'],
#  350849052: ['Mineur en Technologies biomédicales',
#   'Sciences et technologies du vivant'],
#  350861389: ['Microtechnique', 'Génie électrique et électronique'],
#  351053875: ['Sciences et technologies du vivant'],
#  352055084: ['Science et génie des matériaux'],
#  352059100: ['Science et génie des matériaux'],
#  352059163: ['Science et génie des matériaux'],
#  352059962: ['Science et génie des matériaux'],
#  352067537: ['Sciences et technologies du vivant'],
#  352072600: ['Hors plans'],
#  352252328: ['Sciences et technologies du vivant',
#   'Mineur en Systems Engineering'],
#  352254973: ['Bioingénierie', 'Sciences et technologies du vivant - master'],
#  352617902: ['Management, technologie et entrepreneuriat',
#   'Mineur en Management, technologie et entrepreneuriat',
#   'Mineur en Systems Engineering'],
#  352624843: ['Management, technologie et entrepreneuriat',
#   'Mathématiques',
#   'Mineur en Management, technologie et entrepreneuriat'],
#  352625368: ['Management, technologie et entrepreneuriat',
#   'Mineur en Management, technologie et entrepreneuriat'],
#  352632242: ['Management, technologie et entrepreneuriat',
#   'Mineur en Management, technologie et entrepreneuriat',
#   'UNIL - HEC'],
#  353834062: ['Management, technologie et entrepreneuriat',
#   'Mineur en Management, technologie et entrepreneuriat'],
#  353945800: ['Management, technologie et entrepreneuriat',
#   'Mineur en Management, technologie et entrepreneuriat'],
#  353946213: ['Management, technologie et entrepreneuriat',
#   'Mineur en Management, technologie et entrepreneuriat'],
#  354337707: ['Génie électrique et électronique',
#   'Mineur en Technologies spatiales',
#   'Passerelle HES - EL'],
#  354383074: ['Mathématiques', 'Science et ingénierie computationnelles'],
#  354383690: ['Ingénierie physique'],
#  354984919: ['Science et ingénierie computationnelles'],
#  354987130: ['Bioingénierie',
#   'Mineur en Neuroprosthétiques',
#   'Mineur en Neurosciences computationnelles',
#   'Sciences et technologies du vivant - master'],
#  355561756: ['Science et ingénierie computationnelles'],
#  355590267: ['Bioingénierie', 'Sciences et technologies du vivant - master'],
#  355590564: ['Bioingénierie',
#   'Mineur en Neuroprosthétiques',
#   'Sciences et technologies du vivant - master'],
#  355591210: ['Bioingénierie', 'Sciences et technologies du vivant - master'],
#  359060026: ['Génie civil',
#   "Sciences et ingénierie de l'environnement",
#   'Passerelle HES - GC'],
#  400766326: ['Microtechnique',
#   'Mineur en Technologies biomédicales',
#   'Passerelle HES - MT'],
#  405237425: ['Programme Sciences humaines et sociales'],
#  405238132: ['Programme Sciences humaines et sociales'],
#  405250632: ['Programme Sciences humaines et sociales'],
#  414819112: ['Génie civil'],
#  426521225: ['Ingénierie mathématique'],
#  431474304: ['Bioingénierie', 'Physique - master', 'Ingénierie physique'],
#  432433317: ['Génie nucléaire'],
#  438961411: ['Sciences et technologies du vivant - master'],
#  444503507: ['Programme Sciences humaines et sociales'],
#  444523163: ["Sciences et ingénierie de l'environnement"],
#  445435350: ['Programme Sciences humaines et sociales'],
#  445483403: ['Programme Sciences humaines et sociales'],
#  455262375: ['Génie civil', 'Science et ingénierie computationnelles'],
#  467191817: ['Bioingénierie'],
#  468310629: ['Chimie moléculaire et biologique'],
#  652058540: ['Génie civil'],
#  652058942: ['Génie électrique et électronique'],
#  652059419: ['Génie nucléaire'],
#  652061370: ['Informatique'],
#  652076110: ['Systèmes de communication - master'],
#  652076651: ["Sciences et ingénierie de l'environnement"],
#  652077020: ['Ingénierie mathématique'],
#  652077693: ['Génie mécanique'],
#  652078044: ['Microtechnique'],
#  652078287: ['Science et génie des matériaux'],
#  652078498: ['Génie électrique et électronique'],
#  784634759: ['Chimie et génie chimique',
#   'Génie civil',
#   'Mathématiques',
#   'Microtechnique',
#   'Génie électrique et électronique',
#   'Génie mécanique',
#   'Science et génie des matériaux',
#   "Sciences et ingénierie de l'environnement",
#   'Sciences et technologies du vivant',
#   'Systèmes de communication',
#   'Informatique'],
#  784637359: ['Systèmes de communication', 'Informatique'],
#  824161299: ['Bioingénierie',
#   'Génie mécanique',
#   'Mineur en Technologies biomédicales'],
#  824206674: ['Microtechnique'],
#  824210739: ['Microtechnique', 'Génie mécanique'],
#  830854788: ['Génie nucléaire'],
#  830900311: ['Génie civil'],
#  830901136: ['Génie civil'],
#  837364272: ['Mathématiques - master'],
#  837368471: ['Mathématiques - master', 'Ingénierie mathématique'],
#  837370054: ['Mathématiques - master',
#   'Ingénierie mathématique',
#   'Systèmes de communication - master',
#   'Informatique'],
#  837374708: ['Architecture'],
#  838974819: ['Science et génie des matériaux'],
#  838976279: ["Sciences et ingénierie de l'environnement"],
#  838976529: ['Génie mécanique', 'Science et génie des matériaux'],
#  838976977: ['Science et génie des matériaux'],
#  838977426: ['Science et génie des matériaux'],
#  838978162: ['Science et génie des matériaux'],
#  838978869: ['Science et génie des matériaux'],
#  838979534: ['Hors plans'],
#  839100255: ['Bioingénierie'],
#  840801900: ['Science et génie des matériaux'],
#  840814050: ['Mineur en Technologies spatiales',
#   'Science et génie des matériaux'],
#  840843791: ['Management, technologie et entrepreneuriat'],
#  840844976: ['Management, technologie et entrepreneuriat',
#   'Mineur en Management, technologie et entrepreneuriat'],
#  840861451: ['Ingénierie financière'],
#  840861591: ['Ingénierie financière'],
#  842513489: ['Ingénierie financière'],
#  842513650: ['Ingénierie financière'],
#  842513718: ['Management, technologie et entrepreneuriat',
#   'Ingénierie financière'],
#  862953095: ["Gestion de l'énergie et construction durable"],
#  900058271: ['Programme Sciences humaines et sociales'],
#  901865880: ['Programme Sciences humaines et sociales'],
#  938058920: ['Génie civil', 'Passerelle HES - GC'],
#  967657884: ['Science et ingénierie computationnelles'],
#  1046491990: ['Sciences et technologies du vivant'],
#  1156258190: ['Area and Cultural Studies minor'],
#  1494716829: ['Architecture', 'Echange AR'],
#  1494718976: ['Architecture', 'Echange AR'],
#  1496923419: ['Architecture'],
#  1496924504: ['Architecture',
#   'Mineur en Développement territorial et urbanisme'],
#  1497044684: ['Mathématiques - master',
#   'Ingénierie mathématique',
#   'Ingénierie financière',
#   'Science et ingénierie computationnelles'],
#  1497047397: ['Génie civil', 'Science et ingénierie computationnelles'],
#  1499247990: ['Génie mécanique', 'Mineur en Technologies spatiales'],
#  1499248312: ['Génie électrique et électronique', 'Passerelle HES - EL'],
#  1499250198: ['Génie électrique et électronique', 'Passerelle HES - EL'],
#  1499251995: ['Microtechnique',
#   'Génie électrique et électronique',
#   'Passerelle HES - EL'],
#  1499334061: ['Génie électrique et électronique', 'Passerelle HES - EL'],
#  1499336370: ['Génie électrique et électronique', 'Passerelle HES - EL'],
#  1499340075: ['Génie électrique et électronique', 'Passerelle HES - EL'],
#  1499342340: ["Sciences et ingénierie de l'environnement"],
#  1499348352: ['Génie électrique et électronique'],
#  1499350096: ["Gestion de l'énergie et construction durable",
#   'Génie électrique et électronique',
#   'Mineur en Énergie'],
#  1499350407: ["Gestion de l'énergie et construction durable",
#   'Mineur en Technologies spatiales',
#   "Sciences et ingénierie de l'environnement"],
#  1501687491: ['Systèmes de communication - master', 'Informatique'],
#  1513577805: ['Chimie et génie chimique'],
#  1533900991: ['Chimie moléculaire et biologique'],
#  1543013152: ['Bioingénierie', 'Sciences et technologies du vivant - master'],
#  1543121640: ['Management, technologie et entrepreneuriat',
#   'Mineur en Management, technologie et entrepreneuriat',
#   'Mineur en Systems Engineering'],
#  1543121763: ['Management, technologie et entrepreneuriat',
#   'Mineur en Management, technologie et entrepreneuriat',
#   'UNIL - HEC'],
#  1567044774: ['Génie mécanique'],
#  1576313429: ["Sciences et ingénierie de l'environnement"],
#  1577870692: ['Architecture', 'Echange AR', 'Passerelle HES - AR'],
#  1578086108: ['Microtechnique',
#   'Génie électrique et électronique',
#   'Passerelle HES - EL',
#   'Passerelle HES - MT'],
#  1578290162: ['Science et ingénierie computationnelles'],
#  1580209507: ['Programme Sciences humaines et sociales'],
#  1580213011: ['Programme Sciences humaines et sociales'],
#  1580213986: ['Programme Sciences humaines et sociales'],
#  1580214098: ['Programme Sciences humaines et sociales'],
#  1580214404: ['Programme Sciences humaines et sociales'],
#  1580215017: ['Programme Sciences humaines et sociales'],
#  1580215162: ['Programme Sciences humaines et sociales'],
#  1580215916: ['Programme Sciences humaines et sociales'],
#  1580216068: ['Programme Sciences humaines et sociales'],
#  1580216372: ['Programme Sciences humaines et sociales'],
#  1580216381: ['Programme Sciences humaines et sociales'],
#  1580216498: ['Programme Sciences humaines et sociales'],
#  1580217043: ['Programme Sciences humaines et sociales'],
#  1580217054: ['Programme Sciences humaines et sociales'],
#  1580217244: ['Programme Sciences humaines et sociales'],
#  1580217350: ['Programme Sciences humaines et sociales'],
#  1580219781: ['Programme Sciences humaines et sociales'],
#  1580220001: ['Programme Sciences humaines et sociales'],
#  1580220027: ['Programme Sciences humaines et sociales'],
#  1580220177: ['Programme Sciences humaines et sociales'],
#  1580220255: ['Programme Sciences humaines et sociales'],
#  1580272486: ['Sciences et technologies du vivant'],
#  1580488321: ['Programme Sciences humaines et sociales'],
#  1580939449: ['Programme Sciences humaines et sociales'],
#  1581023265: ['Management, technologie et entrepreneuriat',
#   'Mineur en Management, technologie et entrepreneuriat'],
#  1581027726: ['Management, technologie et entrepreneuriat',
#   'Mineur en Management, technologie et entrepreneuriat'],
#  1581729904: ['Programme Sciences humaines et sociales'],
#  1581730596: ['Programme Sciences humaines et sociales'],
#  1581730851: ['Programme Sciences humaines et sociales'],
#  1581730912: ['Programme Sciences humaines et sociales'],
#  1581730988: ['Programme Sciences humaines et sociales'],
#  1581731065: ['Programme Sciences humaines et sociales'],
#  1581731104: ['Programme Sciences humaines et sociales'],
#  1581734542: ['Programme Sciences humaines et sociales'],
#  1581734729: ['Programme Sciences humaines et sociales'],
#  1581734848: ['Programme Sciences humaines et sociales'],
#  1582851784: ["Gestion de l'énergie et construction durable"],
#  1582861537: ['Mineur en Neuroprosthétiques'],
#  1582863195: ['Mineur en Neurosciences computationnelles'],
#  1582864637: ["Gestion de l'énergie et construction durable"],
#  1583926565: ['Mathématiques'],
#  1584194448: ['Ingénierie mathématique'],
#  1584778525: ['Sciences et technologies du vivant'],
#  1585747148: ['Mathématiques'],
#  1590321840: ['Mineur en Développement territorial et urbanisme',
#   "Sciences et ingénierie de l'environnement"],
#  1593341315: ['Génie chimique et biotechnologie'],
#  1657415100: ['Chimie et génie chimique',
#   'Génie civil',
#   'Microtechnique',
#   'Génie électrique et électronique',
#   'Génie mécanique',
#   'Science et génie des matériaux',
#   "Sciences et ingénierie de l'environnement",
#   'Sciences et technologies du vivant',
#   'Systèmes de communication',
#   'Informatique'],
#  1657416728: ["Sciences et ingénierie de l'environnement",
#   'Sciences et technologies du vivant'],
#  1657417551: ['Chimie et génie chimique',
#   'Génie civil',
#   'Microtechnique',
#   'Génie électrique et électronique',
#   'Génie mécanique',
#   'Science et génie des matériaux',
#   "Sciences et ingénierie de l'environnement",
#   'Sciences et technologies du vivant',
#   'Systèmes de communication',
#   'Informatique'],
#  1657417886: ['Génie électrique et électronique',
#   'Génie mécanique',
#   'Microtechnique',
#   'Physique',
#   'Mathématiques'],
#  1657719952: ['Génie civil',
#   "Sciences et ingénierie de l'environnement",
#   'Génie mécanique',
#   'Science et génie des matériaux',
#   'Microtechnique',
#   'Génie électrique et électronique',
#   'Mathématiques',
#   'Physique',
#   'Sciences et technologies du vivant'],
#  1657735730: ['Génie mécanique'],
#  1657739114: ['Génie mécanique'],
#  1658044571: ['Mathématiques', 'Physique'],
#  1658061639: ['Mathématiques', 'Physique'],
#  1658221961: ['Bioingénierie',
#   'Microtechnique',
#   'Génie électrique et électronique',
#   'Mineur en Neuroprosthétiques',
#   'Mineur en Technologies biomédicales'],
#  1659017558: ['Physique'],
#  1659025202: ['Physique'],
#  1659048310: ['Physique'],
#  1659463240: ['Microtechnique'],
#  1661374484: ['Chimie et génie chimique'],
#  1661986440: ['Génie électrique et électronique', 'Génie mécanique'],
#  1669225782: ['Chimie moléculaire et biologique',
#   'UNIL - Sciences forensiques'],
#  1669227005: ['Passerelle HES - CGC'],
#  1669888598: ['Génie électrique et électronique', 'Passerelle HES - EL'],
#  1670037881: ['Hors plans'],
#  1670041842: ['Hors plans'],
#  1670041858: ['Hors plans'],
#  1670041923: ['Génie électrique et électronique'],
#  1670041994: ['Micro and Nanotechnologies for Integrated Systems',
#   'Génie électrique et électronique'],
#  1670042080: ['Génie électrique et électronique'],
#  1670042196: ['Génie électrique et électronique'],
#  1670042209: ['Génie électrique et électronique'],
#  1670043473: ['Génie électrique et électronique'],
#  1670063935: ['Génie électrique et électronique'],
#  1670074783: ['Bioingénierie',
#   'Génie électrique et électronique',
#   'Mineur en Neuroprosthétiques',
#   'Mineur en Technologies biomédicales',
#   'Sciences et technologies du vivant - master'],
#  1670080322: ["Gestion de l'énergie et construction durable",
#   'Microtechnique',
#   'Génie mécanique'],
#  1670084070: ['Génie électrique et électronique'],
#  1676507646: ["Gestion de l'énergie et construction durable",
#   'Génie électrique et électronique',
#   'Mineur en Énergie'],
#  1676565978: ['Génie électrique et électronique',
#   'Information security minor'],
#  1676566727: ['Micro and Nanotechnologies for Integrated Systems'],
#  1676570902: ['Génie électrique et électronique',
#   'Mineur en Technologies biomédicales'],
#  1676846587: ['Génie civil',
#   'Science et génie des matériaux',
#   "Sciences et ingénierie de l'environnement",
#   'Sciences et technologies du vivant',
#   'Sciences et technologies du vivant',
#   'UNIL - Sciences forensiques'],
#  1678499905: ['Génie électrique et électronique'],
#  1678500034: ['Génie électrique et électronique'],
#  1678961803: ['Science et ingénierie computationnelles',
#   'Systèmes de communication - master',
#   'Informatique'],
#  1678982942: ['Sciences et technologies du vivant'],
#  1678983025: ['Sciences et technologies du vivant'],
#  1679266975: ['Sciences et technologies du vivant'],
#  1680039586: ['Bioingénierie',
#   'Mineur en Neuroprosthétiques',
#   'Mineur en Neurosciences computationnelles',
#   'Sciences et technologies du vivant - master'],
#  1680039643: ['Bioingénierie', 'Sciences et technologies du vivant - master'],
#  1680050992: ['Génie civil'],
#  1680235062: ['Architecture', 'Passerelle HES - AR'],
#  1680257605: ['Architecture'],
#  1680262168: ['Architecture'],
#  1680277058: ['Architecture'],
#  1680277127: ['Architecture'],
#  1680279554: ['Architecture',
#   'Mineur en Design intégré, architecture et durabilité'],
#  1680357086: ['UNIL - Géosciences',
#   "Sciences et ingénierie de l'environnement"],
#  1680357972: ['Programme Sciences humaines et sociales'],
#  1680358063: ['Programme Sciences humaines et sociales'],
#  1680358076: ['Programme Sciences humaines et sociales'],
#  1680358144: ['Programme Sciences humaines et sociales'],
#  1680358228: ['Programme Sciences humaines et sociales'],
#  1680358717: ['Programme Sciences humaines et sociales'],
#  1680358821: ['Programme Sciences humaines et sociales'],
#  1680359353: ['Programme Sciences humaines et sociales'],
#  1680359735: ['Programme Sciences humaines et sociales'],
#  1680360041: ['Programme Sciences humaines et sociales'],
#  1680530302: ['Bioingénierie', 'Sciences et technologies du vivant - master'],
#  1680530324: ['Bioingénierie', 'Sciences et technologies du vivant - master'],
#  1680530693: ['Bioingénierie', 'Sciences et technologies du vivant - master'],
#  1680530700: ['Bioingénierie', 'Sciences et technologies du vivant - master'],
#  1680530742: ['Bioingénierie', 'Sciences et technologies du vivant - master'],
#  1680535667: ['Bioingénierie', 'Sciences et technologies du vivant - master'],
#  1684920421: ['Hors plans'],
#  1684920459: ['Physique - master', 'Ingénierie physique'],
#  1685158711: ['Mathématiques'],
#  1685197312: ['Mathématiques - master',
#   'Ingénierie mathématique',
#   'Science et ingénierie computationnelles'],
#  1685212246: ['Mathématiques - master',
#   'Ingénierie mathématique',
#   'Ingénierie financière'],
#  1685303560: ['Mathématiques - master',
#   'Ingénierie mathématique',
#   "Mathématiques pour l'enseignement"],
#  1685570179: ['Génie électrique et électronique'],
#  1687172291: ['Architecture'],
#  1693707617: ['Management, technologie et entrepreneuriat',
#   'Mineur en Management, technologie et entrepreneuriat'],
#  1695517338: ['Programme Sciences humaines et sociales'],
#  1702138731: ['Science et génie des matériaux'],
#  1702466222: ['Systèmes de communication', 'Informatique'],
#  1704192615: ['Systèmes de communication'],
#  1715599381: ['Mineur en Biotechnologie'],
#  1757761712: ['Programme Sciences humaines et sociales'],
#  1769329067: ['Chimie et génie chimique', 'Passerelle HES - CGC'],
#  1769332709: ['Passerelle HES - CGC'],
#  1769332958: ['Chimie moléculaire et biologique',
#   "Gestion de l'énergie et construction durable",
#   'Génie chimique et biotechnologie'],
#  1769339854: ['Chimie moléculaire et biologique'],
#  1769357011: ['Architecture', 'Passerelle HES - AR'],
#  1769400055: ['Architecture'],
#  1769410751: ['Architecture', 'Passerelle HES - AR'],
#  1769414921: ['Architecture'],
#  1769419681: ['Architecture', 'Echange AR'],
#  1769423594: ['Architecture', 'Echange AR'],
#  1769706560: ['Architecture', 'Echange AR'],
#  1770649464: ['Génie civil'],
#  1770651047: ['Génie civil'],
#  1770786181: ["Gestion de l'énergie et construction durable", 'Génie civil'],
#  1770793617: ['Génie civil'],
#  1770844214: ['Sciences et technologies du vivant'],
#  1770857585: ['Hors plans'],
#  1771011730: ['Ingénierie mathématique'],
#  1771015531: ['Hors plans'],
#  1771017288: ['Mathématiques - master',
#   'Ingénierie mathématique',
#   "Mathématiques pour l'enseignement",
#   'Ingénierie financière',
#   'Science et ingénierie computationnelles'],
#  1771067191: ['Bioingénierie', 'Sciences et technologies du vivant - master'],
#  1771067486: ['Sciences et technologies du vivant - master'],
#  1771067819: ['Bioingénierie'],
#  1771068812: ['Sciences et technologies du vivant - master'],
#  1771071124: ['Sciences et technologies du vivant - master'],
#  1771071455: ['Sciences et technologies du vivant - master'],
#  1771072469: ['Bioingénierie'],
#  1771072563: ['Bioingénierie'],
#  1771072572: ['Sciences et technologies du vivant - master'],
#  1771072592: ['Sciences et technologies du vivant - master'],
#  1771652313: ['Génie civil',
#   'Génie mécanique',
#   "Sciences et ingénierie de l'environnement",
#   'Mineur en Systems Engineering',
#   'Passerelle HES - GM',
#   'Passerelle HES - GC'],
#  1771690442: ['Génie électrique et électronique',
#   'Physique - master',
#   'Ingénierie physique'],
#  1771693280: ['Génie nucléaire', 'Physique - master', 'Ingénierie physique'],
#  1771703752: ['Génie mécanique'],
#  1771705517: ['Génie mécanique', 'Science et génie des matériaux'],
#  1771712588: ['Science et génie des matériaux'],
#  1771714259: ['Science et génie des matériaux'],
#  1771714545: ['Science et génie des matériaux'],
#  1776023686: ['Microtechnique', 'Passerelle HES - MT'],
#  1776024041: ['Microtechnique',
#   'Génie électrique et électronique',
#   'Physique - master',
#   'Ingénierie physique'],
#  1776027743: ['Microtechnique', 'Génie électrique et électronique'],
#  1776047660: ['Microtechnique'],
#  1776050537: ['Micro and Nanotechnologies for Integrated Systems',
#   'Microtechnique',
#   'Génie électrique et électronique'],
#  1776059601: ['Génie électrique et électronique', 'Passerelle HES - EL'],
#  1776060714: ['Génie électrique et électronique'],
#  1776060814: ['Génie électrique et électronique'],
#  1776060846: ['Génie électrique et électronique'],
#  1776060937: ["Gestion de l'énergie et construction durable",
#   'Génie électrique et électronique',
#   'Mineur en Énergie'],
#  1776066822: ['Ingénierie financière'],
#  1781858447: ['Architecture'],
#  1781858692: ['Architecture',
#   'Mineur en Design intégré, architecture et durabilité'],
#  1789653698: ['Systèmes de communication'],
#  1790138559: ['Systèmes de communication', 'Informatique'],
#  1790138595: ['Systèmes de communication', 'Informatique'],
#  1790169567: ['Systèmes de communication'],
#  1790207913: ['Systèmes de communication - master', 'Informatique'],
#  1790254853: ['Systèmes de communication - master', 'Informatique'],
#  1799962043: ['Architecture', 'Passerelle HES - AR'],
#  1800382716: ["Sciences et ingénierie de l'environnement"],
#  1802440133: ['Mathématiques'],
#  1802451772: ['Mathématiques'],
#  1802553523: ['Mathématiques - master', 'Ingénierie mathématique'],
#  1803204353: ['Physique - master', 'Ingénierie physique'],
#  1803277152: ['Programme Sciences humaines et sociales'],
#  1803280149: ['Programme Sciences humaines et sociales'],
#  1803284776: ['Programme Sciences humaines et sociales'],
#  1803285306: ['Programme Sciences humaines et sociales'],
#  1803659663: ['Programme Sciences humaines et sociales'],
#  1803668078: ['Génie nucléaire'],
#  1803745771: ["Mathématiques pour l'enseignement"],
#  1803746018: ["Mathématiques pour l'enseignement"],
#  1807233617: ['Mineur en Neuroprosthétiques',
#   'Mineur en Neurosciences computationnelles',
#   'Sciences et technologies du vivant - master'],
#  1807734531: ['Mathématiques - master', 'Ingénierie mathématique'],
#  1807738465: ['Science et génie des matériaux'],
#  1818673603: ['Programme Sciences humaines et sociales'],
#  1823866136: ['Programme Sciences humaines et sociales'],
#  1864673347: ['Bioingénierie', 'Sciences et technologies du vivant - master'],
#  1864673356: ['Bioingénierie', 'Sciences et technologies du vivant - master'],
#  1887887330: ['Génie mécanique'],
#  1887888382: ["Gestion de l'énergie et construction durable",
#   'Génie mécanique',
#   'Science et ingénierie computationnelles'],
#  1887888435: ["Gestion de l'énergie et construction durable",
#   'Génie mécanique',
#   'Science et ingénierie computationnelles'],
#  1887888591: ['Systèmes de communication', 'Informatique'],
#  1888084194: ['Microtechnique', 'Passerelle HES - MT'],
#  1888393325: ['Science et génie des matériaux'],
#  1888395138: ['Science et génie des matériaux'],
#  1888395338: ['Science et génie des matériaux'],
#  1888395622: ['Science et génie des matériaux'],
#  1888400347: ['Architecture'],
#  1888401365: ['Architecture'],
#  1888402399: ['Architecture'],
#  1888402628: ['Science et génie des matériaux'],
#  1888788429: ['Systèmes de communication',
#   'Informatique',
#   'Passerelle HES - IN',
#   'Passerelle HES - SC'],
#  1888829730: ['Systèmes de communication - master', 'Informatique'],
#  1889072595: ['Architecture'],
#  1889078840: ['Architecture', 'Echange AR'],
#  1889079000: ['Architecture', 'Echange AR'],
#  1889085700: ['Architecture'],
#  1889181461: ['Génie civil'],
#  1889230132: ['Systèmes de communication - master', 'Informatique'],
#  1889234532: ["Sciences et ingénierie de l'environnement"],
#  1890132722: ["Gestion de l'énergie et construction durable",
#   'Génie électrique et électronique'],
#  1898238663: ['Ingénierie financière'],
#  1898331930: ['Micro and Nanotechnologies for Integrated Systems'],
#  1898529993: ['Passerelle HES - CGC'],
#  1898535955: ['Chimie moléculaire et biologique'],
#  1898551900: ['Mathématiques'],
#  1898553613: ['Mathématiques'],
#  1898557621: ['Mathématiques'],
#  1898563769: ['Mathématiques - master',
#   'Ingénierie mathématique',
#   "Mathématiques pour l'enseignement"],
#  1898563805: ['Mathématiques - master',
#   'Ingénierie mathématique',
#   "Mathématiques pour l'enseignement"],
#  1898576185: ['Mathématiques - master',
#   'Ingénierie mathématique',
#   "Mathématiques pour l'enseignement"],
#  1899737319: ['Management, technologie et entrepreneuriat',
#   'Mineur en Management, technologie et entrepreneuriat'],
#  1899816322: ['Management, technologie et entrepreneuriat',
#   'Mineur en Management, technologie et entrepreneuriat'],
#  1899816746: ['Management, technologie et entrepreneuriat',
#   'Mineur en Management, technologie et entrepreneuriat'],
#  1899818511: ['Mineur en Systems Engineering'],
#  1906433714: ['Architecture', 'Echange AR'],
#  1906438210: ['Architecture', 'Echange AR'],
#  1908341947: ['Programme Sciences humaines et sociales'],
#  1908362115: ['Programme Sciences humaines et sociales'],
#  1908418027: ['Programme Sciences humaines et sociales'],
#  1908418130: ['Programme Sciences humaines et sociales'],
#  1908419376: ['Programme Sciences humaines et sociales'],
#  1908425640: ['Programme Sciences humaines et sociales'],
#  1908428435: ['Programme Sciences humaines et sociales'],
#  1908428897: ['Programme Sciences humaines et sociales'],
#  1909733620: ['Management, technologie et entrepreneuriat',
#   'Mineur en Management, technologie et entrepreneuriat'],
#  1911192181: ['Programme Sciences humaines et sociales'],
#  1913487410: ['Génie électrique et électronique',
#   'Physique - master',
#   'Ingénierie physique'],
#  1919143539: ['Génie nucléaire'],
#  1919567689: ['Programme Sciences humaines et sociales'],
#  1919570518: ['Programme Sciences humaines et sociales'],
#  1921237690: ['Systèmes de communication', 'Informatique'],
#  1927284144: ['Génie mécanique'],
#  1927284194: ['Microtechnique'],
#  1928513209: ['Science et génie des matériaux'],
#  1932629392: ['Génie civil'],
#  1932632950: ['Génie civil'],
#  1932791826: ['Génie civil'],
#  1932794331: ['Génie civil'],
#  1934635827: ['Architecture', 'Echange AR'],
#  1941543671: ['Génie civil', 'Mineur en Énergie'],
#  1954058871: ['Programme Sciences humaines et sociales'],
#  1954059570: ['Programme Sciences humaines et sociales'],
#  1964500347: ['Ingénierie financière'],
#  1994879246: ['Mineur en Design intégré, architecture et durabilité']}

# %%
#sanity check
assert(set(sections.keys()).issubset(my_courses))

# %%
# export the sections
import csv
with open('./data/output/sections.csv', 'w') as csv_file:
    writer = csv.writer(csv_file)
    for key, value in sections.items():
        line = str(key) + '\t'
        for section in value:
            line += section + '|'
        line = line[:-1] #remove last separator
        writer.writerow([line])
